# %%
import json
import time

import requests
from bs4 import BeautifulSoup
import datetime
import csv

def get_data():
    with open("labirint.csv", "w", encoding = 'utf-8') as file:
        writer = csv.writer(file)

        writer.writerow(
            (
                "Название книги",
                "Автор",
                "Издательство",
                "Цена со скидкой",
                "Цена без скидки",
                "Процент скидки",
                "Наличие на складе"
            )
        )

    
    
    headers = {
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    url = "https://www.labirint.ru/genres/2308/?available=1&paperbooks=1&display=table"
    response = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    
    pages_count = int(soup.find("div", class_="pagination-numbers").find_all("a")[-1].text)
    books_data = []
    for page in range(1, pages_count + 1):
    #for page in range(1, 2):
        url = f"https://www.labirint.ru/genres/2308/?available=1&paperbooks=1&display=table&page={page}"

        response = requests.get(url=url, headers=headers)
        soup = BeautifulSoup(response.text, "lxml")

        books_items = soup.find("tbody", class_="products-table__body").find_all("tr")
        for bi in books_items:
            book_data = bi.find_all("td")

            try:
                book_title = book_data[0].find("a").text.strip()
            except:
                book_title = "Нет названия книги"
            print(book_title)
            
            try:
                book_author = book_data[1].text.strip()
            except:
                book_author = "Нет автора"

            try:
                # book_publishing = book_data[2].text
                book_publishing = book_data[2].find_all("a")
                book_publishing = ":".join([bp.text for bp in book_publishing])
            except:
                book_publishing = "Нет издательства"
            
            try:
                book_new_price = int(book_data[3].find("div", class_="price").find("span").find("span").text.strip().replace(" ", ""))
            except:
                book_new_price = "Нет нового прайса"
            
            try:
                book_old_price = int(book_data[3].find("span", class_="price-gray").text.strip().replace(" ", ""))
            except:
                book_old_price = "Нет старого прайса"
            
            try:
                book_sale = round(((book_old_price - book_new_price) / book_old_price) * 100)
            except:
                book_sale = "Нет скидки"
            
            try:
                book_status = book_data[-1].text.strip()
            except:
                book_status = "Нет статуса"
            
            '''
            print(book_title)
            print(book_author)
            print(book_publishing)
            print(book_new_price)
            print(book_old_price)
            print(book_sale)
            print(book_status)
            print('#'*10)
            '''
            
            books_data.append(
                {
                    "book_title": book_title,
                    "book_author": book_author,
                    "book_publishing": book_publishing,
                    "book_new_price": book_new_price,
                    "book_old_price": book_old_price,
                    "book_sale": book_sale,
                    "book_status": book_status
                }
            )
            
            with open("labirint.csv", "a", encoding = 'utf-8') as file:
                writer = csv.writer(file)

                writer.writerow(
                    (
                        book_title,
                        book_author,
                        book_publishing,
                        book_new_price,
                        book_old_price,
                        book_sale,
                        book_status
                    )
                )
    print(f"Обработана {page}/{pages_count}")
    time.sleep(1)     
    
    with open(f"labirint.json", "w", encoding = 'utf-8') as file:
        json.dump(books_data, file, indent=4, ensure_ascii=False)        
            
def main():
    get_data()
    

if __name__ == '__main__':
    main()
# Out:
# Алгоритмы обработки текста. 125 задач с решениями
# Аналитика в Power BI с помощью R и Python
# Программирование. Введение в профессию. Том 2. Системы и сети
# Программирование. Введение в профессию. Том 3. Парадигмы
# C#. Алгоритмы и структуры данных. Учебное пособие для вузов
# Python, например
# Изучаем SQL. Генерация, выборка и обработка данных
# Знакомство с программированием на языке Processing
# Arduino. Большая книга рецептов
# Active Directory глазами хакера
# Web-сервер глазами хакера
# JavaScript для глубокого обучения. TensorFlow.js
# Введение в язык Си++
# Оформление программного кода
# Профессиональное программирование на ассемблере x64 с расширениями AVX, AVX2 и AVX-512
# Говорят, в IT много платят. Как построить успешную карьеру разработчика, оставаться востребованным
# Безопасность контейнеров. Фундаментальный подход к защите контейнеризированных приложений
# Те же 10 вопросов через 20 лет. Офис и компьютер
# Программирование. Введение в профессию. Том 1. Азы программирования
# Имитационное моделирование процессов и систем в АПК. Учебное пособие
# ВОСХОД программиста
# JavaScript с нуля
# Наглядный CSS
# Scala. Профессиональное программирование
# Основы разработки iOS-приложений на C# с помощью Xamarin. Учебное пособие для вузов
# Основы разработки iOS-приложений на C# с помощью Xamarin.СПО
# Программирование.Сборник задач.СПО
# Математическое программирование.СПО
# Программирование на ассемблере х64. От начального уровня до профессионального использования AVX64
# Обработка и представление данных в MS Excel. СПО
# Вычисления в кольцах некоммутативных многочленов
# Веб-дизайн для начинающих. HTML, CSS, JavaScript и веб-графика
# Разработка веб-приложений на WordPress
# ASP.NET Core 3 с примерами на C# для профессионалов
# PowerShell для сисадминов
# Защита данных. От авторизации до аудита
# Создаем динамические веб-сайты на PHP
# Теория вероятностей и математическая статистика в среде MATLAB. Учебное пособие
# HTTP/2 в действии
# Методика моделирования динамики октокоптера
# Байесовская статистика. Star Wars, LEGO, резиновые уточки и многое другое
# Python. Лучшие практики и инструменты
# Raspberry Pi 4. Официальное руководство для начинающих
# Laravel 8. Быстрая разработка веб-сайтов на PHP
# Разработка Android-приложений на С# с использованием Xamarin с нуля
# Атаки на веб и WordPress
# Linux глазами хакера
# Вероятностное программирование
# C# 9.0. Карманный справочник
# Восстановление данных. Практическое руководство
# Теория автоматического управления (с использованием MATLAB - SIMULINK). Учебное пособие
# Обработка естественного языка. Python и spaCy на практике
# Python для финансовых расчетов
# Разработка и анализ компьютерных алгоритмов
# Научное программирование на Python
# C#. Алгоритмы и структуры данных (+CD). СПО
# C#. Основы программирования (+CD). СПО
# C#. Программирование 2D и 3D векторной графики (+CD). СПО
# Алгоритмизация и программирование. Практикум. СПО
# Организация беспроводных Ad Hoc и Hot Spot сетей в среде ОС Windows
# Построение распределенных систем на базе WebSocket. Учебное пособие
# Практическое введение в язык программирования Си. СПО
# Проектирование и разработка WEB-приложений. Введение в frontend и backend разработку. СПО
# Введение в язык Си++
# Оформление программного кода
# Простой Python для опытных программистов
# Профессиональная разработка на Python
# Программируй & типизируй
# Основы Python. Научитесь мыслить как программист
# SimInTech. Преобразователи автономных источников электроэнергии
# Принятие решений и феномен неопределенности. Учебное пособие
# JavaScript. Готовые программы. Учебное пособие
# JavaScript. Готовые программы. СПО
# TypeScript быстро
# C# 8 и .NET Core. Разработка и оптимизация
# Разработка базы данных в Access. Учебное пособие
# Основы программирования на языке С. Учебное пособие
# Java. Быстрый старт
# Python. Быстрый старт
# Kubernetes. Лучшие практики. Построение эффективных приложений
# C++ для профи
# Интеллектуальные информационные системы и методы искусственного интеллекта
# Современный скрапинг веб-сайтов с помощью Python
# Инструментальные средства разработки программного обеспечения Системы Fossil
# Эффективный Java. Тюнинг кода на Java 8, 11 и дальше
# Веб-разработка с применением Node и Express. Полноценное использование стека JavaScript
# gRPC. Запуск и эксплуатация облачных приложений. Go и Java для Docker и Kubernetes
# Python. Сборник упражнений
# Совершенный алгоритм. Алгоритмы для NP-трудных задач
# Стильный Java. Код, который работает всегда и везде
# Внедрение зависимостей на платформе .NET
# От монолита к микросервисам
# Электроника. Занимательная электроника
# Проекты с использованием контроллера Arduino
# Глубокое обучение. Легкая разработка проектов на Python
# Паттерны проектирования для C# и платформы .NET Core
# Структуры и алгоритмы обработки данных. Учебник для СПО
# Численные методы и программирование. Учебное пособие для СПО
# Web-программирование на JavaScript. Учебное пособие для СПО
# Технология разработки программного обеспечения. Учебное пособие для СПО
# “Непрактичный” Python. Занимательные проекты для тех, кто хочет поумнеть
# Разработка приложений на Swift 5.1 и SwiftUI с нуля
# WordPress с нуля
# Совершенный софт. Совершенный софт — совершенная
# Spark в действии. С примерами Java, Python и Scala
# Изучаем Power Query. Наглядный подход к подключению и преобразованию данных из множества источников
# Еще более эффективный Agile
# Секреты Python Pro
# Программирование на Python в примерах и задачах
# Моделирование и оптимизация процессов управления в технологических системах. Учебник
# Квантовые вычисления. Прикладной подход
# JavaScript. Полное руководство
# Проектирование информационных систем. Методы и средства структурно-функционального проектирования
# Структуры дан.в C#.Лин.и нелин.динамич.структ.СПО
# Проектирование информационных систем. Стандартизация, техническое документирование информ. систем
# Системы отображения информации. Дискретные индикаторы. Учебник для вузов
# Инфокоммуникационные системы. Протоколы,интерфейсы. Практикум. СПО
# Нечеткое моделирование и управление в технических системах. Учебное пособие для вузов
# Мультимедийные технологии. Учебник для СПО
# Swift. Основы разработки приложений под iOS, iPadOS и macOS
# Система модулей Java
# Как программировать на С++
# Игровой движок. Программирование и внутреннее устройство
# Принципы юнит-тестирования
# Простой Python. Современный стиль программирования
# Kotlin. Сборник рецептов. Предметный подход
# Олимпиадное программирование
# Компьютерная арифметика. Учебное пособие. СПО (+CD)
# Программирование. Практикум. Учебное пособие
# Системное программное обеспечение информационных мультимедиасистем. Учебное пособие
# Распределенные системы
# Основы алгоритмизации и программирования на PythonОсновы алгоритмизации и программирования на Python
# Android. Программирование для профессионалов
# Алгебра и геометрия с примерами на Python. Учебное пособие
# Корпоративные информационные системы. Администрирование сетевого домена. Учебное пособие
# Введение в программирование на языке Visual Basic for Applications (VBA). Учебное пособие
# Hello World! Программирование для детей и взрослых
# Методология создания информационных систем. Учебное пособие
# Разработка бизнес-приложений на платформе "1С: Предприятие". Учебное пособие
# Время UNIX. A History and a Memoir
# Проектирование информационных систем. Учебное пособие. СПО
# Интеграция управления программой и системной инженерии. Методы, инструменты и организационные систем
# Современный JavaScript для нетерпеливых
# Инфокоммуникационные системы. Учебник
# Инфокоммуникационные системы. Учебник
# Программирование на Rust. Официальный гайд
# Проектирование информационных систем. Учебное пособие
# Профессиональный TypeScript. Разработка масштабируемых JavaScript-приложений
# Подробное руководство по DAX: бизнес-аналитика с Microsoft Power Bl, SQL Server Analysis Services
# Хаос-инжиниринг
# Цифровая обработка сигналов на системном уровне с использованием LabVIEW
# Спортивное программирование
# Django 3.0. Практика создания веб-сайтов на Python
# Python и наука о данных для чайников
# Криптография - наука о тайнописи. Учебное пособие
# Искусство тестирования программ
# Введение в гибридные технологии разработки мобильных приложений. Учебное пособие
# Прикладное программирование. Учебное пособие
# Python для программирования криптовалют
# Прикладное машинное обучение без учителя с использованием Python
# Алгоритмы оптимизации
# Мифический человеко-месяц, или Как создаются программные системы
# Разработка приложений на С++ с использованием Boost. Рецепты, упрощающие разработку вашего приложени
# JavaScript. 20 уроков для начинающих
# PHP и MySQL. 25 уроков для начинающих
# Программирование для Android
# Ловушка для багов. Полевое руководство по веб-хакингу
# Программирование квантовых компьютеров. Базовые алгоритмы и примеры кода
# Site Reliability Workbook. Практическое применение
# Разработка и реализац.портальн.решений: Практикум
# Транспортная логистика (линейное программирование). Учебное пособие
# Генетические алгоритмы на Python
# Kotlin. Программирование на примерах
# Взлом. Приемы, трюки и секреты хакеров
# HTML и CSS. 25 уроков для начинающих
# Алгоритмы и программы. Язык С++. Учебное пособие
# Основы объектно-ориентированного программирования на базе языка С#. Учебное пособие
# Обработка естественного языка в действии
# Golang для профи. Работа с сетью, многопоточность, структуры данных и машинное обучение с Go
# Программируем с PyTorch. Создание приложений глубокого обучения
# Эффективный TypeScript. 62 способа улучшить код
# Istio. Приступаем к работе
# Принципы разработки программных пакетов. Проектирование повторно используемых компонентов
# Апокалипсис криптографии. Подготовка к криптовалютным вычислениям
# Проектирование веб-API
# Игра в цифры. Как аналитика позволяет видеоиграм жить лучше
# Мобильные роботы на базе ESP32 в среде Arduino IDE
# Программирование на VBA в Excel 2019. Самоучитель
# Програмирование микроконтроллеров AVR. От Arduino к ассемблеру
# Глубокое обучение в картинках. Визуальный гид по искусственному интеллекту
# Глубокое обучение с подкреплением. AlphaGo и другие технологии
# Чистый Agile. Основы гибкости
# Spring Boot 2. Лучшие практики для профессионалов
# Python. Искусственный интеллект, большие данные и облачные вычисления
# Эволюционные нейросети на языке Python
# Алгоритмы обучения с подкреплением на Python
# Цифровой синтез. Практический курс
# Системное программирование. Лабораторные работы. Учебное пособие
# Криптография и взлом шифров на Python
# Машинное обучение. Карманный справочник. Краткое руководство по методам структурированного машинного
# Программист-прагматик
# Учимся программировать с примерами на Python
# Параллельное программирование на C++ с помощью библиотеки TBB
# Предметно-ориентированное проектирование в Enterprise Java
# Генеративное глубокое обучение. Творческий потенциал нейронных сетей
# Распределенные системы реального времени. Теория и практика
# Программирование на Python. Базовый курс
# Нативная разработка мобильных приложений. Перекрестный справочник для iOS и Android
# Паттерны объектно-ориентированного проектирования
# Применение пакета MATLAB и SIMULINK для анализа электрических цепей. Том 1
# Управление памятью в .NET для профессионалов
# Terraform. Инфраструктура на уровне кода
# Языки программирования и методы трансляции. Учебное пособие
# Исследование операций и методы оптимизации. Учебное пособие
# Грокаем технологию Биткоин
# Веб-компоненты в действии
# Машинное обучение на R: экспертные техники для прогностического анализа
# Head First. Изучаем Go
# Архитектура компьютерных систем. Курс лекций. Учебное пособие
# Разработка программных модулей программного обеспечения для компьютерных систем. Прикладное програм.
# Основы программирования информационного контента. Учебное пособие
# Численные методы. Учебник
# C++ для инженерных и научных расчетов
# Введение в глубокое обучение
# Язык C. Самое необходимое
# Машинное обучение без лишних слов
# Легкий способ выучить Python 3 еще глубже
# Практикум по численным методам в вычислительных средах matlab и mathcad. Учебное пособие
# Программирование на языке Пролог для задач искусственного интеллекта. Введение в логическое программ
# Информационные системы и программирование. Специалист по информационным системам. Выпускная квалифик
# Совершенный алгоритм. Жадные алгоритмы и динамическое программирование
# Паттерны Kubernetes. Шаблоны разработки собственных облачных приложений
# Обучение с подкреплением
# Рекомендательные системы на практике
# Flutter на практике. Прокачиваем навыки мобильной разработки с помощью открыт. фреймворка от Googlе
# Машинное обучение для алгоритмической торговли на финансовых рынках. Практикум
# Java Concurrency на практике
# Kubernetes для DevOps: развертывание, запуск и масштабирование в облаке
# C# 8.0. Карманный справочник
# Введение в информационный поиск
# Нейронные сети и глубокое обучение. Учебный курс
# Разработка веб-приложений с помощью Node.js, MongoDB и Angular. Исчерпывающее руководство
# Изучаем Python. Программирование игр, визуализация данных, веб-приложения
# Разработка игр на Unity 2018 за 24 часа
# R. Книга рецептов. Проверенные рецепты для статистики, анализа и визуализации
# Графовые алгоритмы. Практическая реализация на платформах  Apache Spark и Neo4j
# Функциональное программирование на С++. Как сделать свои программы изящными с помощью технологии фун
# Теория автоматического управления (с использованием MATLAB-SIMULINK). Практикум. Учебное пособие
# Python. Непрерывная интеграция и доставка
# Программирование GPU при помощи Python и CUDA. Исследуйте высокопроизводительные параллельные вычисл
# Объектно-ориентированный подход
# Разработка с использованием квантовых компьютеров
# C++. Практика многопоточного программирования
# Laravel. Полное руководство
# Java. Библиотека профессионала. Том 2. Расширенные средства программирования
# Изучаем Python. Том 2
# Программирование логических контроллеров. Учебное пособие
# Волшебство Kotlin
# Методы и алгоритмы решения прикладных задач дискретной оптимизации. Учебное пособие
# Обработка естественного языка с TensorFlow
# Информационные системы и программирование. Администратор баз данных. Учебник
# Программное обеспечение компьютерных сетей. Учебное пособие
# Моделирование химико-технологических процессов. Принципы применения пакетов компютерн. математики
# Клиентские технологии веб-программирования: JavaScript и DOM
# Основы глубокого обучения. Создание алгоритмов для искусственного интеллекта следующего поколения
# Алгоритмы. Вводный курс
# DevOps для современного предприятия
# Программирование встроенных систем на С++ 17. Создание универсальных и надежных встроенных решений
# ELIXIR в действии
# Глубокое обучение для поисковых систем
# Введение в программирование на языке Visual Basic for Applications (VBA). Учебное пособие
# Байесовский анализ на Python
# Состязательные сети. Проекты
# Прикладное глубокое обучение. Подход к пониманию глубоких нейронных сетей на основе метода кейсов
# JavaFX
# Основы программирования на языке С. Учебное пособие
# Программирование на языке Си. Учебное пособие
# Разработка мобильных приложений на C# для iOS и Android
# JavaScript для профессионалов
# C. Полное руководство. Классическое издание
# NGINX. Книга рецептов. Продвинутые рецепты высокопроизводительной   балансировки нагрузки
# Как стать хакером
# Шаблоны проектирования для облачной среды
# SQL для чайников
# Введение в архитектуру программного обеспечения. Учебное пособие
# Библия C#
# Архитекторы интеллекта. Вся правда об искусственном интеллекте от его создателей
# Глубокое обучение и игра в го
# Разработка игр на Unreal Engine 4 за 24 часа
# Изучаем C#
# Квантовые вычисления для настоящих айтишников
# Знакомство с PyTorch: глубокое обучение при обработке естественного языка
# 1400 задач по программированию
# Бессерверные приложения на JavaScipt
# Head First. Kotlin
# Программирование в среде Delphi. Создание проектов. Учебное пособие
# Программирование в среде Delphi. Основные команды. Первые проекты
# Основы алгоритмизации и программирования на языке Microsoft Visual Basic. Учебное пособие
# MATLAB 6.5 SP1/7/7 SP1/7 SP2 + Simulink 5/6. Инструменты искусственного интеллекта и биоинформатики
# Компьютерный анализ и моделирование электрических цепей переменного тока в среде MATLAB
# VHDL. Справочное пособие по основам языка
# Компьютерный анализ и моделирование электрических цепей переменного тока в среде MATLAB
# Компьютерный анализ и моделирование электрических цепей постоянного тока в среде MATLAB
# Компьютерный анализ и моделирование электрических цепей постоянного тока в среде MATLAB
# Компьютерный анализ четырехполюсников с помощью MATLAB
# Компьютерный анализ четырехполюсников с помощью MATLAB
# Компьютерный спектральный анализ сигналов с помощью MATLAB
# Компьютерный спектральный анализ сигналов с помощью MATLAB
# Непрерывное развитие API. Правильные решения в изменчивом технологическом ландшафте
# Глубокое обучение в биологии и медицине
# Современный язык Java. Лямбда-выражения, потоки и функциональное программирование
# Программирование на языке высокого уровня. Программирование на языке Object Pascal. Учебное пособие
# Управление качеством программного обеспечения. Учебник
# Математическое программирование. Учебное пособие
# Практика нейросетевого моделирования. Учебное пособие
# Python и анализ данных
# Алгоритмы эволюционной оптимизации
# Машинный интеллект. Очерки по теории машинного обучения и искусственного интеллекта
# Клиентские технологии веб-дизайна. HTML5 и CSS3. Учебное пособие
# Технология разработки программного обеспечения. Учебное пособие
# C++ за 21 день
# Рефакторинг с использованием шаблонов
# Java для всех
# Docker на практике
# Swift подробно
# Java. Справочник разработчика
# Оптимизация программ на C++. Проверенные методы повышения производительности
# Самоучитель Ruby
# Блокчейн. Руководство для начинающих разработчиков
# PHP глазами хакера
# Идиомы и паттерны проектирования в современном С++
# Изучаем Python. Том 1
# Рефакторинг кода на JavaScript. Улучшение проекта существующего кода
# Data mining. Извлечение информации из Facebook, Twitter, LinkedIn, Instagram, GitHub
# Путь Python. Черный пояс по разработке, масштабированию, тестированию и развертыванию
# Безопасный DevOps. Эффективная эксплуатация систем
# Язык программирования Python: практикум. Учебное пособие
# Машинное обучение и безопасность. Защита систем с помощью данных и алгоритмов
# Разработка интеллектуальных систем. Введение в технологию машинного обучения
# Теория вероятностей и математическая статистика в среде MATLAB. Учебное пособие
# PHP: объекты, шаблоны и методики программирования
# Объектно-ориентированное программирование с примерами на C#. Учебное пособие
# Применение пакета MATLAB для анализа резонансных явлений в электрических цепях. Учебно-мет. пособие
# Применение пакета MATLAB для анализа резонансных явлений в электрических цепях. Учебно-мет. пособие
# Программирование. Сборник задач. Учебное пособие
# Python. Книга Рецептов
# Глубокое обучение с подкреплением на Python. OpenAI Gym и TensorFlow для профи
# Основы Java
# Машинное обучение с использованием Python. Сборник рецептов
# Грокаем глубокое обучение
# Практика реактивного программирования в SPRING 5
# Нейросетевые методы в обработке естественного языка
# Практическая энциклопедия Arduino
# Предиктивное моделирование на практике
# Микросервисы. Паттерны разработки и рефакторинга
# Выразительный JavaScript. Современное веб-программирование
# Системы счисления, алгоритмизация и программирование. Учебное пособие
# Объектно-ориентированное программирование. Учебник
# Практическое введение в программную инженерию. Учебное пособие
# Проектирование цифровых устройств на ПЛИС. Учебное пособие
# Введение в технологии контейнеров и Kubernetes
# Логическое проектирование и верификация систем на SystemVerilog
# C# для чайников
# Глубокое обучение. Готовые решения
# Изучаем TypeScript 3
# Парадигма программирования. Учебное пособие
# Введение в веб-разработку на языке JavaScript. Учебное пособие
# Программирование компьютерной графики
# Высокопроизводительный код на платформе .NET
# Совершенный алгоритм. Графовые алгоритмы и структуры данных
# {Вы не знаете JS} Асинхронная обработка и оптимизация
# {Вы не знаете JS} Замыкания и объекты
# {Вы не знаете JS} Типы и грамматические конструкции
# Основы теории вейвлетов. Вейвлеты в Matlab
# Изучаем React
# Python для чайников
# Введение в рекурсивное программирование
# Изучение сложных систем с помощью Python.
# Вероятностное программирование на Python. Байесовский вывод и алгоритмы
# JavaScript для чайников
# Легкий способ выучить Python 3
# Конкурентность и параллелизм на платформе .NET. Паттерны эффективного проектирования
# Jenkins 2. Приступаем к работе. Создайте свой конвейер развертывания для автоматизации следующего п.
# Реактивное программирование на С++. Проектирование параллельных и асинхронных приложений с использов
# Изображение квантовых процессов. Начальный курс квантовой теории и рассуждений на диаграммах
# Unreal Engine VR для разработчиков
# Язык программирования Python. Практикум. Учебное пособие
# Django 2 в примерах
# Глубокое обучение без математики. Том 1. Основы
# Программирование в среде Lazarus. Учебное пособие
# Введение в программную инженерию. Учебник
# Программирование и основы алгоритмизации.Теоретические основы и примеры реализации численных методов
# Программное обеспечение компьютерных сетей и web-серверов. Учебное пособие
# Технологии параллельного программирования. Учебное пособие
# Глубокое обучение и TensorFlow для профессионалов. Математический подход к построению систем
# Введение в анализ алгоритмов
# Наш код. Ремесло, профессия, искусство
# Практикум по решению задач на ЭВМ в среде Delphi. Учебное пособие
# Анализ вредоносных программ
# Java. Библиотека профессионала. Том 1. Основы
# JavaScript. Карманный справочник
# Применение UML 2.0 и шаблонов проектирования
# Программирование на Javascript для чайников
# Язык программирования C++. Краткий курс
# Численные методы и программирование. Учебное пособие
# Kafka Streams в действии. Приложения и микросервисы для работы в реальном времени
# Микросервисы и контейнеры Docker
# Проектирование и разработка WEB-приложений. Введение в frontend и backend разработку на JavaScript
# Биометрическая защита. Обзор технологии
# Легкий способ выучить Java
# Искусственный интеллект для чайников
# GraphQL. Язык запросов для современных веб-приложений
# Современные технологии программирования. Разработка Windows-приложений на языке С#. Учебник. Том 2
# Компьютерное зрение. Теория и алгоритмы
# Java. Оптимизация программ. Практические методы повышения производительности приложений в JVM
# Vue.js в действии
# HTML и CSS. Разработка и дизайн веб-сайтов
# Искусство программирования на R. Погружение в большие данные
# Базовые средства программирования на Visual Basic в среде VisualStudio Net. Практикум. Учебное пособ
# Алгоритмизация и программирование. Практикум. Учебное пособие
# HTML5 и CSS3 для чайников
# Структуры и алгоритмы обработки данных. Линейные структуры. Учебное пособие
# Самоучитель игры на Паскале. ABC и немного Турбо
# Создание веб-сайта для чайников
# Алгоритмические трюки для программистов
# Unity и C#. Геймдев от идеи до реализации
# PostgreSQL 11. Мастерство разработки
# Распределенные системы. Паттерны проектирования
# Django 2.1. Практика создания веб-сайтов на Python
# TensorFlow для глубокого обучения
# CSS для профи
# Разработка АСУТП в среде WinCC. Учебное пособие
# Автоматизация программируемых сетей
# Разработка бизнес-приложений на платформе "1С:Предприятие". Учебное пособие
# Базовые средства программирования на Visual Basic в среде VisualStudio .NET. Учебное пособие
# Прикладная обработка биомедицинских изображений в среде MATLAB. Учебное пособие
# Язык программирования С++. Специальное издание
# Изучаем pandas
# Умные мобильные проекты с TensorFlow
# C++. Полное руководство. Классическое издание
# Spring 5 для профессионалов
# Искусственный интеллект с примерами на Python. Создание приложений искусственного интеллекта
# Основы машинного обучения для аналитического прогнозирования. Алгоритмы, рабочие примеры
# Разработка SCADA-систем. Учебное пособие
# Прикладной анализ текстовых данных на Python. Машинное обучение и создание приложений обработки
# Язык и среда программирования R. Учебное пособие
# Прагматичный ИИ. Машинное обучение и облачные технологии
# Самоучитель системного администратора
# Внедрение Splunk 7
# Java за 24 часа
# Машинное обучение и TensorFlow
# Spring. Все паттерны проектирования
# Дискретная математика. Учимся программировать в Wolfram Mathematica
# Большие данные. Принципы и практика построения масштабируемых систем обработки данных в реальном вр.
# Современные технологии программирования: разработка Windows-приложений на языке С#. Том 1
# Основы технологий баз данных. Учебное пособие
# Mathematica 5/6/7. Полное руководство
# Простой Python просто с нуля
# Управление программными проектами. Стандарты, модели
# Моделирование объектов управления в MatLab. Учебное пособие
# Основы алгоритмизации и программирования. Практикум. ФГОС
# Программирование на C# для начинающих. Особенности языка
# Архитектура вычислительных систем и Ассемблер
# Delphi. Программирование в примерах и задачах. Практикум: Учебное пособие
# Delphi. Программирование в примерах и задачах. Практикум. Учебное пособие
# Web-аппликации в интернет-маркетинге. Проектирование, создание и применение. Практическое пособие
# Суперкомпьютерные вычисления: практический подход
# Java. Эффективное программирование
# Создаем динамические веб-сайты с помощью PHP, MySQL, JavaScript, CSS и HTML5
# DevOps для ИТ-менеджеров
# Kubernetes в действии
# Смарт-карты и информационная безопасность
# CSS. Карманный справочник
# Изучаем регулярные выражения
# Пользовательские истории. Гибкая разработка программного обеспечения
# Паскаль для школьников. Учебное пособие
# Python. Экспресс-курс
# Java. Руководство для начинающих
# Алгоритмы. Построение и анализ
# Изучай Erlang во имя добра!
# Разработка чат-ботов и разговорных интерфейсов
# Программируй на Haskell
# Конфигурирование и моделирование в системе "1С: Предприятие". Учебник
# Python. Справочник. Полное описание языка
# Теоретический минимум по Big Data. Всё что нужно знать о больших данных
# HTML, JavaScript, PHP и MySQL. Джентльм.наб. Изд.5
# Проекты с использованием контроллера Arduino
# Основы программирования на языке Python
# Методы научных исследований в программной инженерии
# Структуры данных в C#. Линейные и нелинейные динамические структуры. Учебное пособие
# Основы тестирования и верификации программного обеспечения
# Работа с BigData в облаках. Обработка и хранение данных с примерами из Microsoft Azure
# Unity в действии. Мультиплатформенная разработка на C#
# Решение задач на современном C++
# Python 3. Самое необходимое
# Разработка программных приложений в среде BlackBox. Учебное пособие
# Технологии интеллектуального анализа данных. Учебное пособие
# Осваиваем C++17 STL. Используйте компоненты стандартной библиотеки в C++17 STL в полной мере
# Начинаем программировать на Python
# Python 3 и PyQt 5. Разработка приложений. 2-е издание
# Angular. Сборник рецептов
# Исследование операций
# Компиляторы. Краткий справочник
# Структуры данных и алгоритмы
# Язык программирования C# 7 и платформы .NET и .NET Core
# Шаблоны C++. Справочник разработчика
# Java Persistence API и Hibernate
# Байесовские модели. Байесовская статистика на языке Python
# Ядро ORACLE. Внутреннее устройство для администраторо и разработчиков баз данных
# Apache Kafka. Потоковая обработка и анализ данных
# Site Reliability Engineering. Надежность и безотказность как в Google
# Akka в действии
# Безопасность разработка в Agile-проектах
# Чистый Python. Тонкости программирования для профи
# Теория измеримых множеств и мультимножеств
# Введение в распределенное моделирование в среде NetLogo
# Искусственный интеллект .NET. Речь, язык и поиск
# Элегантный SciPy
# Изучаем Java EE. Современное программирование для больших предприятий
# Стандартная библиотека Python 3. Справочник с примерами
# Олимпиадное программирование
# Язык декларативного программирования XAML
# Математика на Python. Часть 1. Элементы линейной алгебры
# Облачные технологии поддержки решения задач анализа безубыточности. Монография
# Разработка игр и теория развлечений
# Прикладное программирование на С/С++: с нуля
# Программист-фанатик
# C# 7 и .NET Core. Кросс-платформенная разработка для профессионалов
# Компьютерные вирусы и антивирусы: взгляд программиста
# Практическая статистика для специалистов Data Science. 50 важнейших понятий
# Основы объектно-ориентированного программирования на базе языка С#. Учебное пособие
# Программная инженерия. Учебное пособие
# Прикладное программирование. Учебное пособие
# Программирование на C# для начинающих. Основные сведения
# Алгоритмы для чайников
# Объектно-ориентированное проектирование: концепции и программный код
# Хакинг. Искусство эксплойта
# Глубокое обучение на Python
# C# 7.0. Справочник. Полное описание языка
# Java SE 9. Базовый курс
# Идеальный программист. Как стать профессионалом разработки ПО
# Python. Разработка на основе тестирования
# Теоретический минимум по Computer Science. Все что нужно программисту и разработчику
# Чистый код. Создание, анализ и рефакторинг
# Qt 5.10. Профессиональное программирование на C++
# Паттерны проектирования на платформе .NET
# Линейная алгебра и линейное программирование для экономистов. Учебник
# Программирование на Ардуино. От простого к сложному
# Unity для разработчика. Мобильные мультиплатформенные игры
# Запускаем Ansible
# Современный Java. Рецепты программирования
# Сам себе программист. Как научиться программировать и устроиться в Ebay?
# Программное обеспечение геодезии, фотограм, кадастра, инж.из.
# Собираем устройства для тестов на проникновение
# Самоучитель PHP 7
# Блокчейн. Разработка приложений
# Java. Карманный справочник
# Путь скрам-мастера. #ScrumMasterWay
# Чистая архитектура. Искусство разработки программного обеспечения
# Объектно Ориентированное Программирование
# Простая Математика для Простых Программистов
# Простой учебник программирования
# Потоковая обработка данных. Конвейер реального времени
# Java для чайников
# Computer Science. Основы программирования на Java, ООП, алгоритмы и структуры данных
# Психбольница в руках пациентов. Алан Купер об интерфейсах
# OpenCV и Java. Обработка изображений и компьютерное зрение
# Высоконагруженные приложения. Программирование, масштабирование, поддержка
# Head First. Паттерны проектирования. Обновленное юбилейное издание
# Английский язык в программировании и информационных системах (СПО). Учебник
# Глубокое обучение с точки зрения практика
# Думай как программист. Креативный подход к созданию кода. C++ версия
# Релевантный поиск с использованием Elasticsearch и Solr
# Программирование на языке Rust. Цветное издание
# Angular 4. Быстрая разработка сверхдинамичных Web-сайтов на TypeScript и PHP
# Алгоритмы для начинающих. Теория и практика для разработчика
# Микросервисы на платформе.NET
# Реактивные шаблоны проектирования
# Android. Сборник рецептов. Задачи и решения для разработчиков приложений
# Официальное руководство Cisco по подготовке к сертификационным экзаменам CCENT/CCNA ICND1 100-105
# Язык R в задачах науки о данных. Импорт, подготовка, обработка, визуализация и моделирование данных
# Теория и практика делового общения для разработчиков программного обеспечения и IT-менеджеров
# Глубокое обучение. Погружение в мир нейронных сетей
# PHP7 для начинающих с пошаговыми инструкциями
# Анализ социальных медиа на Python
# Глубокое обучение (цветная)
# Прямые и обратные задачи восстановления изображений, спектроскопии и томографии с MatLab (+CD)
# Наиболее эффективное программирование на C#. 50 способов улучшения кода
# Функциональное программирование на JavaScript. Как улучшить код JavaScript-программ
# Разработка операционной системы и компилятора. Проект Оберон
# CodeVisionAVR. Пособие для начинающих
# Scala. Профессиональное программирование
# Искусство алгоритмизации
# Java 9. Полный обзор нововведений
# Kotlin в действии
# Конкурентное программирование на Scala
# Крупномасштабное машинное обучение вместе с Python
# Программирование на Clojure
# C# 7.0. Карманный справочник. Скорая помощь для программистов на C# 7.0
# Адаптивный код. Гибкое кодирование с помощью паттернов проектирования и принципов SOLID
# Секреты JavaScript ниндзя
# Машинное обучение с использованием библиотеки Н2О
# Python для сложных задач. Наука о данных и машинное обучение
# Создаем нейронную сеть
# Библиотека Keras - инструмент глубокого обучения
# Визуализация данных с помощью библиотеки D3.js 4.x
# Raspberry Pi. Сборник рецептов. Решение программных и аппаратных задач
# JavaScript в примерах и задачах
# Практикум по параллельному программированию
# Программирование командных оболочек в Unix, Linux и OS X
# Рефакторинг. Улучшение проекта существующего кода
# Введение в язык Pascal. Учебное пособие
# Изучаем программирование на Python
# Математическое программирование. Учебное пособие
# jQuery в действии
# Шаблоны проектирования Node.JS
# SCALA для нетерпеливых
# Практикум по проектированию на языках VerilogHDL и SystemVerilog. Учебное пособие
# C#. Основы программирования. Учебное пособие
# C#. Программирование 2D и 3D векторной графики (+CD)
# Разработка современных веб-приложений. Анализ предметных областей и технологий
# Vulkan. Руководство разработчика
# Введение в машинное обучение с помощью Python. Руководство для специалистов по работе с данными
# Машинное обучение
# Среда динамического моделирования технических систем SimInTech
# Алгоритмы. Справочник с примерами на C, C++, Java и Python
# Изучаем JavaScript. Руководство по созданию современных веб-сайтов
# Постигая Agile. Ценности, принципы, методологии
# Софт за 30 дней. Как Scrum делает невозможное возможным
# Изучаем OpenCV 3
# Семь языков за семь недель. Практическое руководство по изучению языков программирования
# Принципы и методы создания надежного программного обеспечения АСУТП. Методическое пособие
# Задачи по программированию
# Flash MX для профессиональных программистов. Учебное пособие
# Основы программирования
# Программирование на Java для начинающих
# Экстремальное программирование. Разработка через тестирование
# Javascript и jQuery. Интерактивная веб-разработка
# Предметно - ориентированное проектирование. Самое основное
# Введение в Elixir. Введение в функциональное программирование
# Моделирование аукционов
# Пользовательские истории. Искусство гибкой разработки ПО
# Как самому написать мобильную 2D-игру
# Python и машинное обучение
# Проектирование пользовательского интерфейса Android
# Программирование на C в примерах и задачах
# Прикладная криптография. Протоколы, алгоритмы и исходный код на C
# ASP.NET Core MVC с примерами на C# для профессионалов
# Стек, или Путешествие туда и обратно
# Программирование на Visual Basic для начинающих
# Язык программирования С++ (стандарт С++11). Краткий курс
# Реактивное программирование с использованием RxJava
# Грокаем алгоритмы. Иллюстрированное пособие для программистов и любопытствующих
# Изучаем PHP 7. Руководство по созданию интерактивных веб-сайтов
# Не заставляйте меня думать
# Основы Data Science и Big Data. Python и наука о данных
# Go на практике
# Использование Docker
# Методы разработки математических моделей и вычислительный эксперимент на базе пакета MATLAB
# Программирование систем числового программного управления. учебное пособие (+CD)
# Гибкая разработка программ на Java и C++. Принципы, паттерны и методики
# Цифровая обработка сигналов на языке Python
# Программирование на C++ в примерах и задачах
# Cassandra. Полное руководство
# Изучаем Angular 2
# Разработка обслуживаемых программ на языке C#
# Разработка обслуживаемых программ на языке Java
# XBRL для чайников
# Основы программирования. Учебник с практикумом
# Разработка геоприложений на языке Python
# Инженерия требований
# Системы искусственного интеллекта. Учебное пособие
# Сбор данных в Интернете на языке R
# Unity 5.x. Программирование искусственного интеллекта в играх
# Программирование микроконтроллеров. Стратегия и тактика
# Ruby on Rails для начинающих. Изучаем разработку веб-приложений на основе Rails
# Автоматизация рутинных задач с помощью Python. Практическое руководство для начинающих
# PHP 7
# Анализ сетей (графов) в среде R. Руководство пользователя
# Основы проектирования в Autodesk Inventor 2016
# Простой Python. Современный стиль программирования
# Linux. Карманный справочник
# Введение в системы баз данных
# Bootstrap в примерах
# Вычислительная геометрия. Алгоритмы и приложения
# Разработка веб-приложений в ReactJS
# Непрерывное развертывание ПО. Автоматизация процессов сборки, тестирования и внедрения новых версий
# Карьера программиста
# Введение в статистическое обучение с примерами на языке R
# Современное программирование с нуля!
# Android NDK. Руководство для начинающих
# Скрапинг веб-сайтов с помощью Python. Сбор данных из современного интернета
# Моделирование антенных устройств в Matlab с использованием пакета расширения Antenna Toolbox
# Основы вычислений и программирования в пакете MathCAD PRIME. Учебное
# Алгоритмы и программы. Язык С++. Учебное пособие
# Управление электронными устройствами на С++. Разработка практических приложений
# C# 6.0. Справочник. Полное описание языка
# Swift. Карманный справочник. Программирование в среде iOS и ОS X
# Графовые базы данных. Новые возможности для работы
# Руководство по микропроцессорному обеспечению
# Чисто функциональные структуры данных
# Программирование компьютерного зрения на языке Python
# UML Проектирование систем реального времени, распределенных и параллельных приложений
# Программирование на C для чайников
# Прикладные задачи оптимизации. Модели, методы, алгоритмы
# Анализ больших наборов данных
# Построение компиляторов
# Современный PHP. Новые возможности и передовой опыт
# MATLAB. Теория и практика
# Веб-программирование для чайников
# Интерфейс. Основы проектирования взаимодействия
# Введение в надежное и безопасное распределенное программирование
# Дискретная оптимизация. Модели, методы, алгоритмы решения прикладных задач
# C# 6.0. Карманный справочник
# Алгоритмы на C++
# Практика программирования
# Реализация методов предметно-ориентированного проектирования
# Эффективное программирование на C++. Практическое программирование на примерах
# Алгоритмы. Теория и практическое применение
# Python. К вершинам мастерства
# Введение в ECMAScript 6
# Искусство создания сценариев в Unity
# Программирование мобильных устройств на платформе .Net Compact Framework
# Разработка приложений для iPhone, iPad и iPod touch с использованием iOS SDK
# Silverlight 5 с примерами на C# для профессионалов
# Искусство программирования. Том 2. Получисленные алгоритмы
# C# 5.0.Справочник. Полное описание языка
# C# для профессионалов. Тонкости программирования
# Java EE 7. Основы
# Java SE 8. Вводный курс
# Joomla! Для профессионалов
# Microsoft Exchange Server 2013. Полное руководство
# WinRT. программирование на C# для профессионалов
# Программирование для iOS 7. Основы Objective-C, Xcode и Cocoa
# Руководство для программиста на Java. 75 рекомендаций по написанию надежных и защищенных программ
# Язык программирования C++. Базовый курс
# ASP.NET MVC 5 с примерами на C# 5.0 для профессионалов
# Python. Карманный справочник
# Swift. Разработка приложений в среде Xcode для iPhone и iPad с использованием iOS SDK
# Искусственный интеллект. Современный подход
# Искусство программирования. Том 1. Основные алгоритмы
# Компиляторы. Принципы, технологии и инструментарий
# Новые сложные задачи на C++. Серия "C++ In-Depth"
# Предметно-ориентированное проектирование (DDD). Структуризация сложных программных систем
# Современное проектирование на C++. Серия "C++ In-Depth"
# Стандарты программирования на С++. 101 правило и рекомендация
# Шаблоны интеграции корпоративных приложений. Проектирование, создание и развертывание решений
# Язык программирования C
# Язык программирования C. Лекции и упражнения
# C# 4.0. Полное руководство
# C++. Базовый курс
# HTML5. Карманный справочник
# Java. Библиотека профессионала. Том 2. Расширенные средства программирования
# Алгоритмы на Java
# Искусство программирования. Том 4А. Комбинаторные алгоритмы. Часть 1
# Программирование. Принципы и практика с использованием C++
# Эффективный и современный С++. 42 рекомендации по использованию C++11 и C++14
# Язык программирования C++. Лекции и упражнения
# Drupal 7. Руководство пользователя
# Joomla 2.5. Руководство пользователя
# C# 5.0 и платформа .NET 4.5 для профессионалов
# C++ для чайников
# Расширение библиотеки STL для С++. Наборы и итераторы (+CD)
# Линейное программирование. Руководство к решению задач
# Поисковая адаптация. Теория и практика
# Методы оптимальных решений. В 2 томах. Том 1. Общие положения. Математическое программирование
# Методы оптимальных решений. В 2 томах. Том 2. Многокритериальность. Динамика. Неопределенность
# Компьютерное моделирование логических процессов. Архитектура и язык решателя задач
# Обработка естественного языка на Java
# Современное логическое программирование на языке Visual Prolog 7.5. Учебник
# Программирование на Python для начинающих
# Автоматизированные информационно-управляющие системы с применением SCADA-системы TRACE MODE
# Язык Swift. Самоучитель
# Изучаем C++ через программирование игр
# Git для профессионального программиста
# Построение систем машинного обучения на языке Python
# JavaScript и jQuery. Исчерпывающее руководство
# MUMPS СУБД. Практика применения и опыт программирования
# Полезное программирование. Уникальное руководство
# MATLAB и SIMULINK для радиоинженеров
# Java EE 7 и сервер приложений GlassFish 4
# Программирование на ассемблере на платформе x86-64
# Семантический веб
# Функциональное программирование на языке Haskell
# Разработка приложений Java EE 7 в NetBeans 8
# Путь Ruby
# Изучаем Spark
# Статистический анализ и визуализация данных с помощью R
# LLVM. Инфраструктура для разработки компиляторов
# OpenGL ES 3.0. Руководство разработчика
# Современный Фортран на практике
# Elastix - общайтесь свободно!
# C/C++ и MS Visual C++ 2012 для начинающих
# От математики к обобщенному программированию
# Квантовые вычисления и функциональное программирование
# Изучаем программирование на JavaScript
# OpenGL 4. Язык шейдеров. Книга рецептов
# Микроконтроллеры AVR семейств Tiny и Mega фирмы ATMEL
# Микроконтроллеры AVR семейства Classic фирмы ATMEL
# Микроконтроллеры AVR семейства Mega. Руководство пользователя
# Проектирование на ПЛИС. Архитектура, средства и методы. Курс молодого бойца
# СУБД для программиста. Базы данных изнутри
# Семь моделей конкуренции и параллелизма за семь недель
# Язык С в XXI веке
# WebGL. Программирование трехмерной графики
# Философия Java
# Адаптивные и инвариантные алгоритмы обнаружения объектов на изображениях и их моделирование в Matla
# EJB 3 в действии
# Обработка неструктурированных текстов. Поиск, организация и манипулирование
# Практическое использование Common Lisp
# Искусство поиска решения в нестандартной задаче
# Разработка требований к программному обеспечению
# Методы обработки и распознавания изображений лиц в задачах биометрии
# Эффективные технологии создания информационных систем
# Программирование на Objective-C
# Лямбда-выражения в Java 8. Функциональное программирование - в массы
# Программирование на языке OCaml
# Шейдеры и эффекты в Unity. Книга рецептов
# Интерфейс JNI. Руководство по программированию и спецификация
# Системная инженерия. Принципы и практика
# Читаем Тьюринга. Путешествие по исторической статье Тьюринга о вычислимости и машинах Тьюринга
# Python на практике
# Параллельное и конкурентное программирование на Haskell
# Платформа Windows Azure
# Программирование на языке Lua
# Параллельное программирование на С++ в действии. Практика разработки многопоточных программ
# Искусство автономного тестирования с примерами на С#
# За пределами "Linux с нуля". Версия 7.4. Том 2
# Эффективное использование С++. 55 верных способов улучшить структуру и код ваших программ
# С для программистов с введением в С11
# Расширение библиотеки jQuery
# .NET Сетевое программирование
# MATLAB. Полный самоучитель
# Разработка одностраничных веб-приложений
# Редкая профессия
# Моделирование электротехнических устройств в MATLAB. SimPowerSystems и Simulink
# С/С++ Процедурное программирование
# Разработка веб-приложений с использованием AngularJS
# Изучай Haskell во имя добра!
# Как написать безопасный код на С++, Java, Perl, PHP, ASP.NET
# Как программировать на С
# Zend Framework 2.0 разработка веб-приложений
# Разработка приложений для Windows Phone. Архитектура, фреймворки, API
# Наиболее эффективное использование С++. 35 новых рекомендаций  по улучшению ваших программ
# Дизайн и эволюция языка С++
# Основы теории вейвлетов. Вейвлеты в MATLAB
# Теория вычислений для программистов
# Алгоритмы и структуры данных. Новая версия для Оберона
# Google App Engine Java и Google Web Toolkit. Разработка Web-приложений
# Программирование для Microsoft Windows 8
# R в действии. Анализ и визуализация данных на языке R
# Оптимизация приложений на платформе .Net
# Изучаем HTML, XHTML и CSS
# Visuai Basic в задачах и примерах
# CLR via C#. Программирование на платформе Microsoft .NET Framework 4.5 на языке C#. 4-е издание
# LabVIEW. Практический курс для инженеров и разработчиков
# Практика программирования на языке Паскаль. Задачи и решения
# Visual FoxPro 9.0. Учебный курс
# Программирование для школьников и студентов. Учебное пособие
# Создание облачных и мобильных приложений на языке F#
# jQuery Mobile. Разработка приложений для смартфонов и планшетов
# Dart в действии
# Архитектура компьютера
# Принципы построения, применения и проектирования компьютерной платформы U-SYS
# Разработка приложений Java EE 6 в NetBeans 7
# Курс практического программирования в Delphi. Объектно – ориентированное программирование. Практикум
# Программирование микроконтроллеров ATMEL на языке C (+CD)
# Введение в теорию языков программирования
# Программирование. Учебник
# MUMPS СУБД Практика применения и опыт программирования
# Spring в действии
# Программирование на языке Go. Разработка приложений XXI века
# C++ AMP. Построение массивно параллельных программ с помощью Microsoft Visual C++
# Оптимизация производительности приложений для iOS. Для профессионалов
# Асинхронное программирование в C# 5.0
# TV-приемники на шасси VESTEL 11АКхх. Телевизионные шасси 11АК20, 11АК30, 11АК36, РТ-92 (+CD)
# Жемчужины проектирования алгоритмов. Функциональный подход. С примерами на языке Haskell
# Программируем микрокомпьютер NXT в LabVIEW
# ATDD. Разработка программного обеспечения через приемочные тесты. Практический подход
# Основы работы с технологией CUDA
# Дневник охотника за ошибками. Путешествие через джунгли проблем безопасности программного обеспеч.
# Изучаем программирование для iPAD. Практич. руководство по созданию приложений для iPAD с ОС iOS 5
# Программирование для Windows на С/С++. В 2-х томах. Том 2
# Создание web-приложений в Silverlight
# Скользкие места С++. Как избежать проблем  при проектировании и компиляции ваших программ
# Цифровая обработка сигналов. Моделирование в Simulink
# XSLT. Сборник рецептов
# Основы Microsoft Visual Studio .NET 2003
# Средства информатизации. Телекоммуникационные технологии
# iPhone. Разработка приложений с открытым кодом
# Курс программирования на языке Си. Учебник
# Профессиональное программирование приложений для iPhone и iPad
# Программирование в Erlang
# JavaFX 2.0. Разработка RIA-приложений
# Программирование для студентов и школьников на примере Small Basic
# Silverlight. Практическое руководство
# PHP. Создание динамических страниц
# Изучаем Java
# Программирование и отладка С/С++ приложений для микроконтроллеров ARM
# Самоучитель Adobe Dreamweaver CS5.5
# Программируем на Python
# LabVIEW в научных исследованиях
# 10 практических устройств на AVR-микроконтроллерах. Книга 2 (+CD)
# Применение Web-стандартов. CSS и Ajax для больших сайтов
# Применение микроконтролеров PIC18. Архитектура, программирование с применением С и ассемблера (+CD)
# Радиолюбительские конструкции на PIC-микроконтроллерах. Книга 1 (+CD)
# Flex 4. Рецепты программирования
# Цифровая обработка сигналов на системном уровне с использованием LabVIEW (+CD)
# Структуры данных и алгоритмы в Java. Классика Computers Science
# 1С: Предприятие 8.2. Коротко о главном. Новые возможности версии 8.2 (+CD)
# "1С.Предприятие 8". Конвертация данных. Обмен данными между прикладными решениями (+CD)
# Как настраивать "1С:Предприятие 8.2" при внедрении (+СD)
# Assembler. Для DOS, Windows и Unix
# Программирование искусственного интеллекта в приложениях
# Постреляционная СУБД Cache 5. Объектно-ориентированная разработка приложений (+CD)
# Программирование на алгоритмическом языке КуМир
# Функциональное программирование на F#
# Нейросети и нейрокомпьютеры
# Введение в UML от создателей языка
# Технологии программирования на Java 2. Распределенные приложения
# Совершенный код. Мастер-класс
# ASP.NET. Сборник рецептов (+CD)
# Самоучитель PHP 5/6
# Разработка Web-портала в ASP.NET.2.0 и SharePoint 2007 (+CD)
# Ассемблер для Windows (+СD)
# Язык программирования Java и среда NetBeans (+DVD)
# C# 3.0. Справочник
# Firebird: руководство разраб баз данных
# Методы программирования. Компьютерные вычисления
# Самоучитель Silverlight 3
# Windows Driver Foundation: разработка драйверов
# Microsoft ASP.NET 2.0. Базовый курс. Мастер-класс
# Exchange Server 2010. Практическое руководство
# Объектно-ориентированное программирование в С++
# Рефакторинг в C# и ASP.NET для профессионалов
# Шаблоны корпоративных приложений
# Silverlight 4. Создание насыщенных Web-приложений
# С++ для начинающих
# Эффективная работа с унаследованным кодом
# Микрокомпьютерные системы управления. Первое знакомство
# Базы данных. Учебник
# Введение в современные САПР. Курс лекций
# Периферийные устройства: интерфейсы, схемотехника, программирование
# Разработка программного обеспечения: управление изменениями
# PIC-микроконтроллеры: архитектура и программирование
# Silverlight 2. Технология создания интернет-приложений
# LabVIEW: стиль программирования
# Справочник по языку Haskell
# Matlab & Simulink. Проектирование мехатронных систем на ПК. Учебное пособие для ВУЗов (+CD)
# Pocket PC. Руководство разработчика
# Аналоговые интерфейсы микроконтроллеров
# Visual C# 2.0.NET. Полное руководство
# Программирование PIC - микроконтроллеров на PicBasic
# Macromedia Authorware 6.0. Разработка мультимедийных учебных курсов
# Компьютерное моделирование полупроводниковых систем в MatLab 6.0. Учебное пособие
# Delphi 2006. Справочное пособие. Язык Delphi, классы, функции Win32 и .NET.
# Visual Basic. Освой на примерах (+CD)
# Обработана 16/16
